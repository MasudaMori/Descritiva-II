# %% [markdown]
# # Módulo 10 atividade 1

# %% [markdown]
# Uma instituição financeira quer conhecer melhor o perfil de renda de seus novos clientes para diversos fins, por exemplo, melhor dimensionar o limite de cartões de crédito dos novos clientes, sem necessariamente solicitar olerites ou documentações que impactem na experiência do seu cliente.
#
# Para isto, conduziu um estudo com alguns clientes, comprovando suas rendas através de olerites e outros documentos, e pretende construir um modelo preditivo para esta renda com base em algumas variáveis que já possui em seu banco de dados.
#
# As variáveis são intuitivas - note que há uma variável 'index' que é um identificador do cliente e que em geral o ```read_csv``` do pandas coloca também uma variável sequencial.
#
# Estes dados estão no arquivo ```previsao_de_renda.csv```. Carregue-o em um *dataframe*.
#
# 1) Avalie a estrutura de correlação das variáveis quantitativas através de um gráfico de "matriz de dispersão" e através da avaliação gráfica da matriz de correlações. Veja se você identifica algum padrão interessante ou que te faça sentido.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Carregando os dados
df = pd.read_csv('previsao_de_renda.csv', index_col='index')

# %%
# Análise exploratória inicial
print(df.head())  # Visualizando as primeiras linhas
print(df.describe())  # Estatísticas descritivas
# Out:
#        Unnamed: 0    data_ref sexo  posse_de_veiculo  posse_de_imovel  \
# index
# 8682            0  2015-01-01    F             False             True
# 12830           1  2015-01-01    M              True             True
# 2885            2  2015-01-01    M              True             True
# 16168           3  2015-01-01    F              True            False
# 12438           4  2015-01-01    M             False            False
#
#        qtd_filhos   tipo_renda           educacao estado_civil  \
# index
# 8682            1  Assalariado         Secundário       Casado
# 12830           0   Empresário         Secundário       Casado
# 2885            2  Assalariado  Superior completo       Casado
# 16168           0   Empresário         Secundário       Casado
# 12438           0  Assalariado         Secundário       Casado
#
#       tipo_residencia  idade  tempo_emprego  qt_pessoas_residencia    mau  \
# index
# 8682             Casa     36       3.575342                    3.0  False
# 12830            Casa     42       0.860274                    2.0  False
# 2885             Casa     31       8.065753                    4.0  False
# 16168            Casa     50       1.208219                    2.0  False
# 12438            Casa     52      13.873973                    2.0  False
#
#          renda
# index
# 8682   3369.24
# 12830  6096.14
# 2885   5658.98
# 16168  7246.69
# 12438  4017.37
#          Unnamed: 0    qtd_filhos        idade  tempo_emprego  \
# count  15000.000000  15000.000000  15000.00000   12466.000000
# mean    7499.500000      0.437267     43.84140       7.750462
# std     4330.271354      0.760594     11.22917       6.780216
# min        0.000000      0.000000     22.00000       0.191781
# 25%     3749.750000      0.000000     34.00000       3.016438
# 50%     7499.500000      0.000000     43.00000       6.016438
# 75%    11249.250000      1.000000     53.00000      10.183562
# max    14999.000000     14.000000     68.00000      42.906849
#
#        qt_pessoas_residencia         renda
# count           15000.000000  15000.000000
# mean                2.219067   4624.632946
# std                 0.922352   4628.571729
# min                 1.000000    159.900000
# 25%                 2.000000   1945.740000
# 50%                 2.000000   3278.260000
# 75%                 3.000000   5642.365000
# max                15.000000  89918.040000

# %%
# Variáveis numéricas

df_num = df.select_dtypes('number')
df_num.head()
# Out:
#        Unnamed: 0  qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia  \
# index
# 8682            0           1     36       3.575342                    3.0
# 12830           1           0     42       0.860274                    2.0
# 2885            2           2     31       8.065753                    4.0
# 16168           3           0     50       1.208219                    2.0
# 12438           4           0     52      13.873973                    2.0
#
#          renda
# index
# 8682   3369.24
# 12830  6096.14
# 2885   5658.98
# 16168  7246.69
# 12438  4017.37

# %%
# Remover a coluna 'Unnamed: 0' do DataFrame df_num
df_num = df_num.drop(columns=['Unnamed: 0'])

# Verificar o resultado
df_num.head()
# Out:
#        qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia    renda
# index
# 8682            1     36       3.575342                    3.0  3369.24
# 12830           0     42       0.860274                    2.0  6096.14
# 2885            2     31       8.065753                    4.0  5658.98
# 16168           0     50       1.208219                    2.0  7246.69
# 12438           0     52      13.873973                    2.0  4017.37

# %%
# Definindo a matriz de correlação

corr_df = df_num.corr()
corr_df
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.364303      -0.074250
# idade                   -0.364303  1.000000       0.323934
# tempo_emprego           -0.074250  0.323934       1.000000
# qt_pessoas_residencia    0.896488 -0.338805      -0.065748
# renda                    0.009567  0.042570       0.394235
#
#                        qt_pessoas_residencia     renda
# qtd_filhos                          0.896488  0.009567
# idade                              -0.338805  0.042570
# tempo_emprego                      -0.065748  0.394235
# qt_pessoas_residencia               1.000000  0.020977
# renda                               0.020977  1.000000

# %%
# Gerando uma visualização gráfica da matriz de correlação

# Definindo o mapa de cores
cmap = sns.diverging_palette(h_neg=150, h_pos=250, as_cmap=True, sep=60, center='light')
# Gerando a figura
sns.clustermap(corr_df, figsize=[7,7], center=0, cmap=cmap)

# %%
#entre a qtd_filhos e qt_pessoas_residencia: A correlação é muito alta (próxima de 1). Isso indica que, em geral, quanto mais filhos uma pessoa tem, maior é o número de pessoas residindo em sua casa. Essa relação é bastante intuitiva.
#entre qtd_filhos e idade: A correlação é negativa e moderada. Isso sugere que, à medida que a idade aumenta, a tendência é ter menos filhos.
#entre tempo_emprego e renda: A correlação é positiva e moderada. Isso indica que, em geral, quanto mais tempo uma pessoa trabalha, maior é sua renda.

# %% [markdown]
# 2) Avalie um gráfico de dispersão (*scatterplot*) específico para as duas variáveis mais correlacionadas com *renda*.

# %%
corr_df
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.364303      -0.074250
# idade                   -0.364303  1.000000       0.323934
# tempo_emprego           -0.074250  0.323934       1.000000
# qt_pessoas_residencia    0.896488 -0.338805      -0.065748
# renda                    0.009567  0.042570       0.394235
#
#                        qt_pessoas_residencia     renda
# qtd_filhos                          0.896488  0.009567
# idade                              -0.338805  0.042570
# tempo_emprego                      -0.065748  0.394235
# qt_pessoas_residencia               1.000000  0.020977
# renda                               0.020977  1.000000

# %%
print(df_num.index.duplicated().any())
# Out:
# True

# %%
df_num = df_num.reset_index(drop=True)

# %%
print(df_num.columns[df_num.columns.duplicated()])
# Out:
# Index([], dtype='object')

# %%
df_num = df_num.loc[:, ~df_num.columns.duplicated()]

# %%
print(df_num[['tempo_emprego', 'renda']].dtypes)
print(df_num[['tempo_emprego', 'renda']].isnull().sum())
# Out:
# tempo_emprego    float64
# renda            float64
# dtype: object
# tempo_emprego    2534
# renda               0
# dtype: int64

# %%
df_num['tempo_emprego'] = pd.to_numeric(df_num['tempo_emprego'], errors='coerce')
df_num['renda'] = pd.to_numeric(df_num['renda'], errors='coerce')
df_num = df_num.dropna(subset=['tempo_emprego', 'renda'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=[15,6])
sns.scatterplot(
    data=df_num,
    x='tempo_emprego',
    y='renda',
    color='blue',
    alpha=.5
)

plt.title('Tempo de emprego x Renda')
plt.show()

# %% [markdown]
# 3) Na su aopinião, há outliers na variável renda?

# %%
# Gerando um gráfico de distribuição da renda

sns.displot(
    df_num, 
    x='renda',
    # bins=50,
    kde=True
)

# %%
# Aplicando um zoom à figura (limitando o eixo y)

fig = sns.displot(
    df_num, 
    x='renda',
    bins=50,
    # kde=True
)

fig.set(ylim=(0, 10))

# %%
#sim

# %% [markdown]
# 4) Calcule o logaritmo da variável renda e repita a sequência de análise

# %%
# Calculando o logaritmo

df_log = df_num.copy()
df_log['renda_log'] = np.log(df_log['renda'])
df_log
# Out:
#        qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia    renda  \
# 0               1     36       3.575342                    3.0  3369.24
# 1               0     42       0.860274                    2.0  6096.14
# 2               2     31       8.065753                    4.0  5658.98
# 3               0     50       1.208219                    2.0  7246.69
# 4               0     52      13.873973                    2.0  4017.37
# ...           ...    ...            ...                    ...      ...
# 14995           1     37       2.046575                    3.0  1193.29
# 14996           1     30      12.079452                    3.0  2519.18
# 14997           0     40       2.161644                    2.0  1586.85
# 14998           0     47       3.295890                    2.0  6975.39
# 14999           0     50       3.049315                    2.0   993.86
#
#        renda_log
# 0       8.122442
# 1       8.715411
# 2       8.640999
# 3       8.888300
# 4       8.298383
# ...          ...
# 14995   7.084469
# 14996   7.831689
# 14997   7.369506
# 14998   8.850144
# 14999   6.901596
#
# [12466 rows x 6 columns]

# %%
# Gerando um gráfico de distribuição 
sns.displot(
    df_log,
    x='renda_log',
    kde=True,
    color='blue',
)

# %%
# Gráfico de dispersão da idade x renda

fig, axes = plt.subplots(1,2)
plt.rc('figure', figsize=(15,6))

ax1 = sns.scatterplot(ax = axes[0], x='idade', y='renda', data=df_log, alpha=.5, color='blue')
ax1.set_title('idade x renda')
ax2 = sns.scatterplot(ax = axes[1], x='idade', y='renda_log', data=df_log, alpha=.5, color='red')
ax2.set_title('idade x renda_log')
# Out:
# Text(0.5, 1.0, 'idade x renda_log')

# %% [markdown]
# 5) A aplicação do LOG você acha que melhorou ou piorou a análise?

# %%
# Calculando o logaritmo

df_log = corr_df.copy()
df_log['renda_log'] = np.log(df_log['renda'])
df_log
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.364303      -0.074250
# idade                   -0.364303  1.000000       0.323934
# tempo_emprego           -0.074250  0.323934       1.000000
# qt_pessoas_residencia    0.896488 -0.338805      -0.065748
# renda                    0.009567  0.042570       0.394235
#
#                        qt_pessoas_residencia     renda  renda_log
# qtd_filhos                          0.896488  0.009567  -4.649473
# idade                              -0.338805  0.042570  -3.156611
# tempo_emprego                      -0.065748  0.394235  -0.930808
# qt_pessoas_residencia               1.000000  0.020977  -3.864334
# renda                               0.020977  1.000000   0.000000

# %%
#piorou. renda 	0.394235	renda_log-0.930808
